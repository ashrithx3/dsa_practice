# %%
group = {}
for word in strs:
    sorted_word = "".join(sorted(word))
    if sorted_word not in group:
        group[sorted_word] = []
    group[sorted_word].append(word)
return list(group.values())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 group = {}
# ----> 2 for word in strs:
#       3     sorted_word = "".join(sorted(word))
#       4     if sorted_word not in group:
#
# NameError: name 'strs' is not defined
